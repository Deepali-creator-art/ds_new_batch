# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.prev=None
        self.next=None
class dbl:
    def __init__(self):
        self.head=None
        self.tail=None
    def append(self,data):
        new_node=Node(data)
        if not self.head:
            self.head=new_node
            self.tail=new_node
        else:
            new_node.prev=self.tail
            self.tail.next=new_node
            self.tail=new_node
    def append_start(self,data):
        new_node=Node(data)
        if not self.head:
            self.head=new_node
            self.tail=new_node
        else:
            new_node.next=self.head
            self.head.prev=new_node
            self.head=new_node
    def addatposition(self,index,data):
        new_node = Node(data)
        current_node = self.head
        position = 0

        if position == index:
            self.appendatstart(data)
        else:
            while(current_node != None and position+1 != index):
                position = position + 1
                current_node = current_node.next
            
            if current_node != None:
                new_node.prev = current_node
                new_node.next = current_node.next
                current_node.next = new_node
                
            
            else:
                print("Index not present")
    def deleteatfirst(self):

        if not self.head:
            return
        else:
            self.head = self.head.next
    def display(self):
        current_node=self.head
        while(current_node):
            print(f"{current_node.data}",end='-->')
            
            current_node=current_node.next
d=dbl()
n1=Node(10)
d.append(n1.data)
d.append(100)
d.append(200)
d.append_start(500)
d.addatposition(2,300)
d.deleteatfirst()
d.display()
# Out:
# 10-->300-->100-->200-->

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.prev=None
        self.next=None
class doublylinkedlist:
    def __init__(self):
        self.head=None
        self.tail=None
    def addelement(self,data):
        new_node=Node(data)
        #if list is empty
        if self.head is None:
            self.head=new_node
            self.tail=new_node
        else:
            new_node.prev=self.tail
            self.tail.next=new_node
            self.tail=new_node
    def addfirst(self,data):
        new_node=Node(data)
        #if list is empty
        if self.head is None:
            self.head=new_node
            self.tail=new_node
        else:
            new_node.next=self.head
            self.head.prev=new_node
            self.head=new_node
    def addatposition(self,index,data):
        new_node = Node(data)
        current_node = self.head
        position = 0

        if position == index:
            self.addfirst(data)
        else:
            while(current_node != None and position+1 != index):
                position = position + 1
                current_node = current_node.next
            
            if current_node != None:
                new_node.prev = current_node
                new_node.next = current_node.next
                current_node.next = new_node
                
            
            else:
                print("Index not present")
            
    def display(self):
        current_node=self.head
        while current_node:
            print(current_node.data,end='<--->')
            current_node=current_node.next
            
            
d1=doublylinkedlist()
d1.addelement('Pratham')
d1.addelement('Pratiksha')
d1.addelement('Ganesh')
d1.addfirst('Deepali')
d1.addatposition(2,'Gauri')
d1.display()
# Out:
# Deepali<--->Pratham<--->Gauri<--->Pratiksha<--->Ganesh<--->
